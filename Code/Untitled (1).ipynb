# %%
import requests
page3=requests.get('https://www.news18.com/cricketnext/news/ipl-auction-2016-all-you-need-to-know-about-the-351-player-cricket-market-1199280.html')
page3
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
soup3 = BeautifulSoup(page3.content, 'html.parser')
#print(soup3.prettify())

# %%
table=soup3.find_all('table',class_='tg')
pname=[]
ptype=[]
pbase=[]
for i in range(1,6):
    for row in table[i].findAll('tr'):
        if(row.findAll('td')):
            name=row.findAll('td')
            pname.append(name[0].get_text().strip())
            ptype.append(name[1].get_text().strip())
            pbase.append(name[2].get_text().strip().replace('₹',''))
print(pbase)
print(len(pbase))
# Out:
# ['2,00,00,000', '2,00,00,000', '2,00,00,000', '2,00,00,000', '1,50,00,000', '1,00,00,000', '50,00,000', '50,00,000', '2,00,00,000', '1,50,00,000', '1,50,00,000', '1,00,00,000', '1,00,00,000', '1,00,00,000', '1,00,00,000', '1,00,00,000', '1,00,00,000', '1,00,00,000', '1,00,00,000', '50,00,000', '50,00,000', '50,00,000', '50,00,000', '50,00,000', '50,00,000', '50,00,000', '50,00,000', '30,00,000', '30,00,000', '30,00,000', '30,00,000', '30,00,000', '30,00,000', '30,00,000', '30,00,000', '20,00,000', '20,00,000', '20,00,000', '20,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '10,00,000', '2,00,00,000', '2,00,00,000
# ...

# %%
import pandas as pd
df16=pd.DataFrame()
df16['Player Name']=pname
df16['Role']=ptype
df16['Base Price']=pbase
df16
# Out:
#                  Player Name         Role   Base Price
# 0              Ishant Sharma       Bowler  2,00,00,000
# 1               Shane Watson  All-Rounder  2,00,00,000
# 2            Kevin Pietersen      Batsman  2,00,00,000
# 3               Yuvraj Singh  All-Rounder  2,00,00,000
# 4                 Dale Steyn       Bowler  1,50,00,000
# 5                Aaron Finch      Batsman  1,00,00,000
# 6             Martin Guptill      Batsman    50,00,000
# 7               Dwayne Smith  All-Rounder    50,00,000
# 8             Michael Hussey      Batsman  2,00,00,000
# 9              Cameron White      Batsman  1,50,00,000
# 10        Mahela Jayawardena      Batsman  1,50,00,000
# 11              David Hussey      Batsman  1,00,00,000
# 12             Usman Khawaja      Batsman  1,00,00,000
# 13                Owais Shah      Batsman  1,00,00,000
# 14                Adam Voges      Batsman  1,00,00,000
# 15               Hashim Amla      Batsman  1,00,00,000
# ...

# %%
import requests

page1 = requests.get("https://www.iplt20.com/stats/2016/player-points")
page1
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
soup1 = BeautifulSoup(page1.content, 'html.parser')

# %%
sb=[]
#sb1=[]
#name=row.findAll('a')lname=row.findAll('span',class_='top-players__last-name')
fours=[]
sixes=[]
wickets=[]
for i in range(0,159):
    sb.append(float(soup1.find_all('td',class_='top-players__pts top-players__padded is-active')[i].get_text().lstrip().rstrip()))
print(len(sb))
for i in range(0,159):
    sixes.append(soup1.find_all('td',class_='top-players__6s')[i].get_text().lstrip().rstrip())
    fours.append(soup1.find_all('td',class_='top-players__4s')[i].get_text().lstrip().rstrip())
    wickets.append(soup1.find_all('td',class_='top-players__w')[i].get_text().lstrip().rstrip())
print(len(fours))
# Out:
# 159
# 159

# %%
table=soup1.find('table',class_='top-players')
sb1=[]
for row in table.find_all('tr'):
    name=row.findAll('a')
    if len(name)==1:
        sb1.append((name[0].get_text().strip().replace(' ','').replace('\n',' ')))
    else:
        if row.findAll('div',class_='top-players__player-name'):
            name1=row.findAll('div',class_='top-players__player-name')
            sb1.append((name1[0].get_text().strip().replace(' ','').replace('\n',' ')))
len(sb1)
# Out:
# 159

# %%
import pandas as pd1
df1=pd1.DataFrame(sb,columns=['points'])
df1['Player Name']=sb1
df1['4s']=fours
df1['6s']=sixes
df1['Wkts']=wickets
df1
# Out:
#      points           Player Name  4s  6s Wkts
# 0     356.5           Virat Kohli  83  38    0
# 1     338.5          David Warner  88  31    0
# 2     319.5         AB deVilliers  57  37    0
# 3     283.0          Shane Watson  14  12   20
# 4     270.0     Bhuvneshwar Kumar   6   1   23
# 5     247.0          Chris Morris  15  12   13
# 6     229.0          Dwayne Smith  35  16    8
# 7     225.0         Andre Russell  10  15   15
# 8     217.0      Moises Henriques  15   6   12
# 9     203.0  Mitchell McClenaghan   2   3   17
# 10    203.0       Dhawal Kulkarni   2   0   18
# 11    201.5     Mustafizur Rahman   0   0   17
# 12    198.5          Dwayne Bravo  11   1   17
# 13    185.5        Quinton deKock  52  13    0
# 14    184.5        Sandeep Sharma   0   0   15
# 15    184.0        Ajinkya Rahane  54   9    0
# 16    183.5          Rohit Sharma  49  16    0
# 17    183.5      Yuzvendra Chahal   0   0   21
# 18    179.5            Axar Patel   4   8   13
# ...

# %%
a=pd1.merge(df16,df1,on='Player Name',how='outer')
a
# Out:
#                Player Name         Role   Base Price  points   4s   6s Wkts
# 0            Ishant Sharma       Bowler  2,00,00,000    52.5    0    0    3
# 1             Shane Watson  All-Rounder  2,00,00,000   283.0   14   12   20
# 2          Kevin Pietersen      Batsman  2,00,00,000    23.0    4    3    0
# 3             Yuvraj Singh  All-Rounder  2,00,00,000   110.0   22   13    0
# 4               Dale Steyn       Bowler  1,50,00,000     5.0    0    0    0
# 5              Aaron Finch      Batsman  1,00,00,000   158.5   45   11    0
# 6           Martin Guptill      Batsman    50,00,000    18.0    3    3    0
# 7             Dwayne Smith  All-Rounder    50,00,000   229.0   35   16    8
# 8           Michael Hussey      Batsman  2,00,00,000     NaN  NaN  NaN  NaN
# 9            Cameron White      Batsman  1,50,00,000     NaN  NaN  NaN  NaN
# 10      Mahela Jayawardena      Batsman  1,50,00,000     NaN  NaN  NaN  NaN
# ...

# %%
df3=a.sort_values(by='points',ascending=False)
df3=df3.reset_index(drop=True)
df3
# Out:
#                  Player Name         Role   Base Price  points   4s   6s Wkts
# 0                Virat Kohli          NaN          NaN   356.5   83   38    0
# 1               David Warner          NaN          NaN   338.5   88   31    0
# 2              AB deVilliers          NaN          NaN   319.5   57   37    0
# 3               Shane Watson  All-Rounder  2,00,00,000   283.0   14   12   20
# 4          Bhuvneshwar Kumar          NaN          NaN   270.0    6    1   23
# 5               Chris Morris          NaN          NaN   247.0   15   12   13
# 6               Dwayne Smith  All-Rounder    50,00,000   229.0   35   16    8
# 7              Andre Russell          NaN          NaN   225.0   10   15   15
# 8           Moises Henriques          NaN          NaN   217.0   15    6   12
# 9            Dhawal Kulkarni       Bowler  2,00,00,000   203.0    2    0   18
# 10      Mitchell McClenaghan          NaN          NaN   203.0    2    3   17
# ...

# %%
sb1='''Shane Watson	20000000	95000000	Sold	Royal Challengers Bangalore
Pawan Negi	3000000	85000000	Sold	Delhi Daredevils
Chris Morris	5000000	70000000	Sold	Delhi Daredevils
Yuvraj Singh	20000000	70000000	Sold	Sunrisers Hyderabad
Mohit Sharma	15000000	65000000	Sold	Kings XI Punjab
Ashish Nehra	20000000	55000000	Sold	Sunrisers Hyderabad
    words=i.split('\t')
    try:
        pname.append(words[0])
        pbase.append(int(words[1]))
        pauction.append(int(words[2]))
        print(words[0],words[1],words[2])
    except IndexError:
        continue
pbase.append('')
pauction.append('')
print(len(pname))
print(len(pbase))
print(len(pauction))
# Out:
# Shane Watson 20000000 95000000
# Pawan Negi 3000000 85000000
# Chris Morris 5000000 70000000
# Yuvraj Singh 20000000 70000000
# Mohit Sharma 15000000 65000000
# Ashish Nehra 20000000 55000000
# Mitchell Marsh 20000000 48000000
# Murugan Ashwin 1000000 45000000
# Carlos Brathwaite 3000000 42000000
# Sanju Samson 20000000 42000000
# Deepak Hooda 1000000 42000000
# Karun Nair 1000000 40000000
# Jos Buttler 15000000 38000000
# Ishant Sharma 20000000 38000000
# Praveen Kumar 5000000 35000000
# Kevin Pietersen 20000000 35000000
# Nathu Singh 1000000 32000000
# Tim Southee 10000000 25000000
# Dwayne Smith 5000000 23000000
# Dinesh Karthik 20000000 23000000
# Dale Steyn 15000000 23000000
# Kyle Abbott 3000000 21000000
# Krunal Pandya 1000000 20000000
# Kane Richardson 20000000 20000000
# Dhawal Kulkarni 20000000 20000000
# Stuart Binny 20000000 20000000
# Rishabh Pant 1000000 19000000
# Jaydev Unadkat 3000000 16000000
# Ankit Rajpoot 1000000 15000000
# John Hastings 10000000 13000000
# ...

# %%
import pandas as pd2
dft=pd2.DataFrame();
dft['Player Name']=pname;
dft['Base Price']=pbase
dft['Auction Price']=pauction
dft=dft.drop(dft.index[121])
dft
# Out:
#                Player Name Base Price Auction Price
# 0             Shane Watson   20000000      95000000
# 1               Pawan Negi    3000000      85000000
# 2             Chris Morris    5000000      70000000
# 3             Yuvraj Singh   20000000      70000000
# 4             Mohit Sharma   15000000      65000000
# 5             Ashish Nehra   20000000      55000000
# 6           Mitchell Marsh   20000000      48000000
# 7           Murugan Ashwin    1000000      45000000
# 8        Carlos Brathwaite    3000000      42000000
# 9             Sanju Samson   20000000      42000000
# 10            Deepak Hooda    1000000      42000000
# 11              Karun Nair    1000000      40000000
# 12             Jos Buttler   15000000      38000000
# 13           Ishant Sharma   20000000      38000000
# 14           Praveen Kumar    5000000      35000000
# 15         Kevin Pietersen   20000000      35000000
# 16             Nathu Singh    1000000      32000000
# ...

# %%
b=pd2.merge(dft,df1,on='Player Name',how='outer')
b=b.sort_values('points',ascending=False)
b
# Out:
#                Player Name Base Price Auction Price  points   4s   6s Wkts
# 121            Virat Kohli        NaN           NaN   356.5   83   38    0
# 122           David Warner        NaN           NaN   338.5   88   31    0
# 123          AB deVilliers        NaN           NaN   319.5   57   37    0
# 0             Shane Watson   20000000      95000000   283.0   14   12   20
# 124      Bhuvneshwar Kumar        NaN           NaN   270.0    6    1   23
# 2             Chris Morris    5000000      70000000   247.0   15   12   13
# 18            Dwayne Smith    5000000      23000000   229.0   35   16    8
# 125          Andre Russell        NaN           NaN   225.0   10   15   15
# 126       Moises Henriques        NaN           NaN   217.0   15    6   12
# 24         Dhawal Kulkarni   20000000      20000000   203.0    2    0   18
# 127   Mitchell McClenaghan        NaN           NaN   203.0    2    3   17
# ...

# %%
namenan=[]
for index,row in b.iterrows():
    if row['Base Price']==-1:
        namenan.append(row['Player Name'])
print(namenan)
print(len(namenan))
# Out:
# []
# 0

# %%
# %store b
# Out:
# Stored 'b' (DataFrame)

# %%
b[]
